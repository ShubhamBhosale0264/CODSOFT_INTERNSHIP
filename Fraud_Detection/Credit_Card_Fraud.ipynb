# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
import sklearn
import imblearn
import xgboost as xgb
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,f1_score
from imblearn.over_sampling import SMOTE
# %matplotlib inline

# %%
data = pd.read_csv(r"creditcard.csv")

# %%
data.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.759061e-12 -8.251130e-13 -9.654937e-13  8.321385e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.649999e-13  4.248366e-13 -3.054600e-13  8.777971e-14 -1.179749e-12
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
sns.countplot(data['Class'])
# Out:
# <Axes: ylabel='count'>

# %%
Drop_Column = data.drop(columns = ['Time' , 'Amount','Class'],axis = 1)

# %%
cols = 5
rows = 6
fig, axs = plot.subplots(rows, cols, figsize=(25, 50))
axs = axs.flatten()

index = 0
for cl in Drop_Column:
    sns.histplot(Drop_Column[cl], ax=axs[index], kde=True) 
    axs[index].set_title(cl)  
    index += 1

plot.tight_layout(pad=0.5,w_pad=0.5,h_pad=5)  

plot.show()

# %%
hist_color = "#1f77b4" 

sns.set_style("whitegrid")  
sns.displot(data['Time'], kde=True, color=hist_color)
plot.tight_layout()

plot.show()
# Out:
# c:\Users\shubh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12920\709572065.py:5: UserWarning: The figure layout has changed to tight
#   plot.tight_layout()

# %%
hist_color = "#1f77b4" 

sns.set_style("whitegrid")  
sns.displot(data['Amount'], kde=True, color=hist_color)
plot.tight_layout()

plot.show()
# Out:
# c:\Users\shubh\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\shubh\AppData\Local\Temp\ipykernel_12920\1449914357.py:5: UserWarning: The figure layout has changed to tight
#   plot.tight_layout()

# %%
cor = data.corr()
plot.figure(figsize=(40,40))
sns.heatmap(cor,annot = True , cmap ='viridis')
# Out:
# <Axes: >

# %%
X = data.drop(columns = ['Class'],axis=1)
Y = data['Class']

# %%
sc = StandardScaler()
X_Scaler = sc.fit_transform(X)
X_Scaler[-1]
# Out:
# array([ 1.64205773, -0.27233093, -0.11489898,  0.46386564, -0.35757   ,
#        -0.00908946, -0.48760183,  1.27476937, -0.3471764 ,  0.44253246,
#        -0.84072963, -1.01934641, -0.0315383 , -0.18898634, -0.08795849,
#         0.04515766, -0.34535763, -0.77752147,  0.1997554 , -0.31462479,
#         0.49673933,  0.35541083,  0.8861488 ,  0.6033653 ,  0.01452561,
#        -0.90863123, -1.69685342, -0.00598394,  0.04134998,  0.51435531])

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size=0.2, random_state=42)
model = xgb.XGBClassifier()
model.fit(X_Train, Y_Train)
Y_Predict = model.predict(X_Test)
print(classification_report(Y_Test, Y_Predict))
print(f1_score(Y_Test, Y_Predict, average='weighted'))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.99      0.79      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.89      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
# 0.99959186710614

# %%
over_sam = SMOTE()
X_Smote , Y_Smote = over_sam.fit_resample(X_Train , Y_Train)

# %%
sns.countplot(Y_Smote)
# Out:
# <Axes: ylabel='count'>

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size=0.2, random_state=42)
model = xgb.XGBClassifier()
model.fit(X_Train, Y_Train)
Y_Predict = model.predict(X_Test)
print(classification_report(Y_Test, Y_Predict))
print(f1_score(Y_Test, Y_Predict, average='weighted'))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.99      0.79      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.99      0.89      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
# 0.99959186710614
